# %%
from scapy.all import *
import scapy.contrib.rtps as rtps
import sys

# %%
conf.iface = "eno2"

# %%
# cap = sniff(filter="udp", store=False, prn=lambda p: dir(p))
cap = sniff(filter="udp", prn=lambda p: dir(p))
# Out:
# ['_PickleType', '__all_slots__', '__annotations__', '__bool__', '__bytes__', '__class__', '__class_getitem__', '__contains__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__iterlen__', '__le__', '__len__', '__lt__', '__module__', '__mul__', '__ne__', '__new__', '__nonzero__', '__orig_bases__', '__parameters__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__rtruediv__', '__setattr__', '__setitem__', '__setstate__', '__signature__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__truediv__', '__weakref__', '_answered', '_defrag_pos', '_do_summary', '_is_protocol', '_name', '_overload_fields', '_pkt', '_resolve_alias', '_show_or_dump', '_superdir', 'add_parent', 'add_payload', 'add_underlayer', 'aliastypes', 'answers', 'build', 'build_done', 'build_paddin
# ...

# %%
packet = cap[56]
packet[UDP].payload.load
rtps_packet = rtps.RTPS(packet[UDP].payload.load)

# %%
rtps_packet.time
# Out:
# 1684302179.4359415

# %%
rtps_packet.show2()
# Out:
# ###[ RTPS Header ]###
#   magic     = 'RTPS'
#   \protocolVersion\
#    |###[ RTPS Protocol Version ]###
#    |  major     = 2
#    |  minor     = 1
#   \vendorId  \
#    |###[ RTPS Vendor ID ]###
#    |  vendor_id = ADLINK - Cyclone DDS
#   \guidPrefix\
#    |###[ RTPS GUID Prefix ]###
#    |  hostId    = 0x110ead7
#    |  appId     = 0x8e4d6911
#    |  instanceId= 0x51fde42a
# ###[ RTPS Message ]###
#      \submessages\
#       |###[ RTPS INFO_TS (0x09) ]###
#       |  submessageId= 0x9
#       |  submessageFlags= E
#       |  octetsToNextHeader= 8
#       |  ts_seconds= 1684300277
#       |  ts_fraction= 1973569780
#       |###[ RTPS DATA (0x15) ]###
#       |  submessageId= 0x15
#       |  submessageFlags= 0x5
#       |  octetsToNextHeader= 140
#       |  extraFlags= 0x0
#       |  octetsToInlineQoS= 16
#       |  readerEntityIdKey= 0x0
#       |  readerEntityIdKind= 0x0
#       |  writerEntityIdKey= 0x4
#       |  writerEntityIdKind= 0x3
#       |  writerSeqNumHi= 0
# ...

# %%
sum(sys.getsizeof(p) for p in cap)
# Out:
# 30008
