# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('~/Downloads/query (62).csv', skiprows=3)

# %%
# Get mean, std, p99, max for the column 'elapsed'
mean = df['elapsed'].mean()
std = df['elapsed'].std()
p99 = df['elapsed'].quantile(0.99)
max = df['elapsed'].max()

print(f'Mean: {mean}')
print(f'Std: {std}')
print(f'P99: {p99}')
print(f'Max: {max}')
# Out:
# Mean: 33.737202118270076
# Std: 28.292305795374027
# P99: 164.0
# Max: 510

# %%
df = pd.read_csv('~/Downloads/query (65).csv', skiprows=3)

# %%
df
# Out:
#         Unnamed: 0  result  table      _field _measurement  \
# 0              NaN     NaN      0  attributes        spans
# 1              NaN     NaN      0  attributes        spans
# 2              NaN     NaN      0  attributes        spans
# 3              NaN     NaN      0  attributes        spans
# 4              NaN     NaN      0  attributes        spans
# ...            ...     ...    ...         ...          ...
# 209703         NaN     NaN   1017  attributes        spans
# 209704         NaN     NaN   1017  attributes        spans
# 209705         NaN     NaN   1017  attributes        spans
# 209706         NaN     NaN   1017  attributes        spans
# 209707         NaN     NaN   1017  attributes        spans
#
#                               _time  _value  fragment_starting_num  \
# 0       2024-06-07T16:34:26.916902Z   13440                      1
# 1       2024-06-07T16:34:26.916994Z   13440                     11
# ...

# %%
# plt.hist(df['elapsed'], range=(0, 100), bins=100)
plt.figure(figsize=(10, 8))

plt.hist(df['elapsed'], range=(0, 14000), bins=14000)
# Out:
# (array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0.0000e+00, 1.0000e+00, 2.0000e+00, ..., 1.3998e+04, 1.3999e+04,
#         1.4000e+04]),
#  <BarContainer object of 14000 artists>)
